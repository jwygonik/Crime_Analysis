# %%
import pandas as pd
import geopy
import pgeocode

# %%
file_to_load = "Resources/LAPD_Police_Stations.csv"

LAPDSTATS_df = pd.read_csv(file_to_load)
LAPDSTATS_df
# Out:
#           LONG        LAT  OBJECTID          DIVISION  \
# 0  -118.289242  33.757661         1            HARBOR
# 1  -118.275394  33.938627         2         SOUTHEAST
# 2  -118.277670  33.970307         3       77TH STREET
# 3  -118.419842  33.991655         4           PACIFIC
# 4  -118.305142  34.010575         5         SOUTHWEST
# 5  -118.256119  34.012356         6            NEWTON
# 6  -118.247294  34.044019         7           CENTRAL
# 7  -118.450780  34.043777         8  WEST LOS ANGELES
# 8  -118.213068  34.045009         9        HOLLENBECK
# 9  -118.342830  34.046748        10          WILSHIRE
# 10 -118.291176  34.050209        11           OLYMPIC
# 11 -118.266980  34.056690        12           RAMPART
# 12 -118.330669  34.095833        13         HOLLYWOOD
# 13 -118.249414  34.119201        14         NORTHEAST
# 14 -118.385859  34.171694        15   NORTH HOLLYWOOD
# 15 -118.445226  34.183743        16          VAN NUYS
# ...

# %%
LAPDSTATS_df = LAPDSTATS_df[["OBJECTID","DIVISION","PREC","LOCATION","ZIP","LONG","LAT"]]
LAPDSTATS_df
# Out:
#     OBJECTID          DIVISION  PREC                           LOCATION  \
# 0          1            HARBOR     5          2175 JOHN S. GIBSON BLVD.
# 1          2         SOUTHEAST    18                   145 W. 108TH ST.
# 2          3       77TH STREET    12                   7600 S. BROADWAY
# 3          4           PACIFIC    14                 12312 CULVER BLVD.
# 4          5         SOUTHWEST     3  1546 MARTIN LUTHER KING JR. BLVD.
# 5          6            NEWTON    13               3400 S. CENTRAL AVE.
# 6          7           CENTRAL     1                     251 E. 6TH ST.
# 7          8  WEST LOS ANGELES     8                   1663 BUTLER AVE.
# 8          9        HOLLENBECK     4                    2111 E. 1ST ST.
# 9         10          WILSHIRE     7                  4861 VENICE BLVD.
# 10        11           OLYMPIC    20               1130 S. VERMONT AVE.
# 11        12           RAMPART     2                    1401 W. 6TH ST.
# ...
