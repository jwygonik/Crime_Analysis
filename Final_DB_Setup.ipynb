# %%
import pandas as pd
import sqlalchemy as sql
import pandas as pd
from config import password
from config import connection

# %%
sql_connection=(f'postgresql://postgres:{password}@{connection}:5432/postgres')

# %%
engine=sql.create_engine(sql_connection)

# %%
engine.table_names()
# Out:
# C:\Users\erica\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# ['crime_dataset']

# %%
df=pd.read_csv('combined_df.csv')
df
# Out:
#      Unnamed: 0  med_age_weight  med_income_weight  \
# 0         90001       2549743.7       1.859720e+09
# 1         90002       1937620.4       1.426340e+09
# 2         90003       4043026.2       3.031933e+09
# 3         90004       2865510.3       2.653570e+09
# 4         90005       2756055.6       2.265993e+09
# ..          ...             ...                ...
# 455       93584        168700.7       7.299566e+07
# 456       93586        415253.5       4.004616e+08
# 457       93590        128363.3       1.101909e+08
# 458       93591        630425.9       4.298193e+08
# 459       93599             0.0       0.000000e+00
#
#      month_housing_costs_weight  total_pop    med_age    med_income  \
# 0                   109830976.0    85439.0  29.842855  21766.634979
# 1                    93298147.0    67896.0  28.538064  21007.714563
# 2                   188588435.0   139506.0  28.981020  21733.352902
# 3                   134322386.0    79367.0  36.104556  33434.173473
# ...

# %%
df = df.rename(columns={'Unnamed: 0':'Zip'})
df
# Out:
#        Zip  med_age_weight  med_income_weight  month_housing_costs_weight  \
# 0    90001       2549743.7       1.859720e+09                 109830976.0
# 1    90002       1937620.4       1.426340e+09                  93298147.0
# 2    90003       4043026.2       3.031933e+09                 188588435.0
# 3    90004       2865510.3       2.653570e+09                 134322386.0
# 4    90005       2756055.6       2.265993e+09                 118253352.0
# ..     ...             ...                ...                         ...
# 455  93584        168700.7       7.299566e+07                   3138422.0
# 456  93586        415253.5       4.004616e+08                  16926589.0
# 457  93590        128363.3       1.101909e+08                   4915482.0
# 458  93591        630425.9       4.298193e+08                  18347515.0
# 459  93599             0.0       0.000000e+00                         0.0
#
#      total_pop    med_age    med_income  month_housing_costs  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 38 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Zip                             460 non-null    int64
#  1   med_age_weight                  449 non-null    float64
#  2   med_income_weight               449 non-null    float64
#  3   month_housing_costs_weight      449 non-null    float64
#  4   total_pop                       449 non-null    float64
#  5   med_age                         447 non-null    float64
#  6   med_income                      447 non-null    float64
#  7   month_housing_costs             447 non-null    float64
#  8   Against Family/Child            95 non-null     float64
#  9   Aggravated Assault              117 non-null    float64
#  10  Burglary                        108 non-null    float64
#  11  Disorderly Conduct              41 non-null     float64
# ...

# %%
# Against Family/Child         
#   Aggravated Assault            
#  Burglary                        
#  Disorderly Conduct           
#  Disturbing the Peace           
#  Driving Under Influence        
#  Drunkeness                      
#  Federal Offenses               
#  Forgery/Counterfeit             
#  Fraud/Embezzlement              
#  Gambling                        
#  Homicide                        
#  Larceny                         
#  Liquor Laws                    
#  Miscellaneous Other Violations 
#  Moving Traffic Violations       
#  Narcotic Drug Laws              
#  Non-Criminal Detention         
#  Other Assaults                  
#  Pre-Delinquency                 
#  Prostitution/Allied             
#  Rape                            
#  Receive Stolen Property         
#  Robbery                         
#  Sex (except rape/prst)        
#  Vehicle Theft                  
#  Weapon (carry/poss)

# %%
columns_to_sum = ['Against Family/Child','Aggravated Assault','Burglary','Disorderly Conduct','Disturbing the Peace','Driving Under Influence','Drunkeness','Federal Offenses','Forgery/Counterfeit','Fraud/Embezzlement','Gambling','Homicide','Larceny','Liquor Laws','Miscellaneous Other Violations','Moving Traffic Violations','Narcotic Drug Laws','Non-Criminal Detention','Other Assaults','Pre-Delinquency','Prostitution/Allied','Rape','Receive Stolen Property','Robbery','Sex (except rape/prst)','Vehicle Theft','Weapon (carry/poss)']

df['Total_Crimes'] = df[columns_to_sum].sum(axis=1)
df
# Out:
#        Zip  med_age_weight  med_income_weight  month_housing_costs_weight  \
# 0    90001       2549743.7       1.859720e+09                 109830976.0
# 1    90002       1937620.4       1.426340e+09                  93298147.0
# 2    90003       4043026.2       3.031933e+09                 188588435.0
# 3    90004       2865510.3       2.653570e+09                 134322386.0
# 4    90005       2756055.6       2.265993e+09                 118253352.0
# ..     ...             ...                ...                         ...
# 455  93584        168700.7       7.299566e+07                   3138422.0
# 456  93586        415253.5       4.004616e+08                  16926589.0
# 457  93590        128363.3       1.101909e+08                   4915482.0
# 458  93591        630425.9       4.298193e+08                  18347515.0
# 459  93599             0.0       0.000000e+00                         0.0
#
#      total_pop    med_age    med_income  month_housing_costs  \
# ...

# %%
df.to_sql('crime_dataset',con=engine,if_exists='replace',index=False)

# %%
df.to_csv('test.csv',index=False)
